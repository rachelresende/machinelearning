# %%
# !pip install yfinance
# !pip install investpy
# !pip install --upgrade pandas-datareader

# %%
from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt #graficos

import yfinance as yf
import investpy as inv
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

# %%
# Índice Ibovespa (^BVSP)
df_ibov = yf.download('^BVSP', start='2020-02-20', end='2021-02-20')
display(df_ibov)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP     ^BVSP
# Date
# 2020-02-20  114586.0  116552.0  114379.0  116518.0   6793000
# 2020-02-21  113681.0  114585.0  112661.0  114585.0   5896200
# 2020-02-26  105718.0  113647.0  105053.0  113647.0   9369800
# 2020-02-27  102984.0  106656.0  102984.0  105711.0  11237700
# 2020-02-28  104172.0  104172.0   99951.0  102984.0  11228400
# ...              ...       ...       ...       ...       ...
# 2021-02-11  119235.0  120283.0  118440.0  118440.0   7567400
# 2021-02-12  119116.0  119763.0  118163.0  119300.0   7655900
# 2021-02-17  120391.0  120573.0  118880.0  119421.0   8326100
# 2021-02-18  119140.0  120845.0  118515.0  120361.0  10720600
# 2021-02-19  118748.0  119250.0  117867.0  119199.0  10402800
#
# [245 rows x 5 columns]

# %%
df_ibov["Close"].plot(figsize=(15, 10))
plt.show()

# %%
# (PETR4.SA)
df_petro = yf.download('PETR4.SA', start='2024-02-01', end='2025-02-20')
display(df_petro)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker       PETR4.SA   PETR4.SA   PETR4.SA   PETR4.SA  PETR4.SA
# Date
# 2024-02-01  33.950745  34.203927  33.215702  33.305541  61629200
# 2024-02-02  33.509716  34.122250  33.501550  33.958910  36485600
# 2024-02-05  33.656723  34.040579  33.428045  33.493380  27703000
# 2024-02-06  33.967079  34.587779  33.705731  33.852740  35474600
# 2024-02-07  34.465271  34.465271  33.828233  33.909906  30648100
# ...               ...        ...        ...        ...       ...
# 2025-02-13  36.320000  36.330002  36.020000  36.200001  15351300
# 2025-02-14  37.439999  37.580002  36.400002  36.439999  40322000
# 2025-02-17  37.669998  37.919998  37.470001  37.639999  22615200
# 2025-02-18  38.360001  38.439999  37.709999  37.720001  44062600
# 2025-02-19  38.439999  38.660000  37.869999  38.110001  32648200
#
# [264 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(df_petro['Close'])
plt.title('Cotação de Fechamento da PETR4')
plt.xlabel('Data')
plt.ylabel('Preço (R$)')
plt.grid(True)
plt.show()

# %%
sns.distplot(df_petro ['Close'])
# Out:
# <ipython-input-68-e6da23e88a89>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_petro ['Close'])
# <Axes: ylabel='Density'>

# %%
df_petro.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker    PETR4.SA    PETR4.SA    PETR4.SA    PETR4.SA      PETR4.SA
# count   264.000000  264.000000  264.000000  264.000000  2.640000e+02
# mean     34.277876   34.624640   33.953072   34.286802  3.605008e+07
# std       1.971561    1.929228    2.000150    1.978128  2.183918e+07
# min      29.115801   29.581327   28.666609   29.132132  1.152660e+07
# 25%      33.084168   33.432775   32.799740   33.173684  2.494202e+07
# 50%      34.287958   34.665270   34.032087   34.402435  3.180545e+07
# 75%      35.788245   36.205489   35.586979   35.823976  3.948555e+07
# max      38.439999   38.660000   37.869999   38.110001  2.303698e+08

# %%
sns.pairplot(df_petro)

# %%
X = df_petro[['High', 'Low', 'Open', 'Volume']]
y = df_petro['Close']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
